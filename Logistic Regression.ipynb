# %%
import numpy as np
import pandas as pd
m1=pd.read_csv('D:\\My Work\\Daily Work\\Bank Data\\bank.csv',sep=';')

# %%
m1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4521 entries, 0 to 4520
# Data columns (total 17 columns):
# age          4521 non-null int64
# job          4521 non-null object
# marital      4521 non-null object
# education    4521 non-null object
# default      4521 non-null object
# balance      4521 non-null int64
# housing      4521 non-null object
# loan         4521 non-null object
# contact      4521 non-null object
# day          4521 non-null int64
# month        4521 non-null object
# duration     4521 non-null int64
# campaign     4521 non-null int64
# pdays        4521 non-null int64
# previous     4521 non-null int64
# poutcome     4521 non-null object
# y            4521 non-null object
# dtypes: int64(7), object(10)
# memory usage: 600.6+ KB

# %%
m1
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %%
m1.job.unique()
# Out:
# array(['unemployed', 'services', 'management', 'blue-collar',
#        'self-employed', 'technician', 'entrepreneur', 'admin.', 'student',
#        'housemaid', 'retired', 'unknown'], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder
l1=LabelEncoder()
m1['job']=l1.fit_transform(m1['job'])

# %%
m1.job.unique()
# Out:
# array([10,  7,  4,  1,  6,  9,  2,  0,  8,  3,  5, 11], dtype=int64)

# %%
m1
# Out:
#       age  job  marital  education default  balance housing loan   contact  \
# 0      30   10  married    primary      no     1787      no   no  cellular
# 1      33    7  married  secondary      no     4789     yes  yes  cellular
# 2      35    4   single   tertiary      no     1350     yes   no  cellular
# 3      30    4  married   tertiary      no     1476     yes  yes   unknown
# 4      59    1  married  secondary      no        0     yes   no   unknown
# ...   ...  ...      ...        ...     ...      ...     ...  ...       ...
# 4516   33    7  married  secondary      no     -333     yes   no  cellular
# 4517   57    6  married   tertiary     yes    -3313     yes  yes   unknown
# 4518   57    9  married  secondary      no      295      no   no  cellular
# 4519   28    1  married  secondary      no     1137      no   no  cellular
# 4520   44    2   single   tertiary      no     1136     yes  yes  cellular
#
#       day month  duration  campaign  pdays  previous poutcome   y
# ...

# %%
m1.marital.unique()
# Out:
# array(['married', 'single', 'divorced'], dtype=object)

# %%
l1=LabelEncoder()
m1['marital']=l1.fit_transform(m1['marital'])

# %%
m1
# Out:
#       age  job  marital  education default  balance housing loan   contact  \
# 0      30   10        1    primary      no     1787      no   no  cellular
# 1      33    7        1  secondary      no     4789     yes  yes  cellular
# 2      35    4        2   tertiary      no     1350     yes   no  cellular
# 3      30    4        1   tertiary      no     1476     yes  yes   unknown
# 4      59    1        1  secondary      no        0     yes   no   unknown
# ...   ...  ...      ...        ...     ...      ...     ...  ...       ...
# 4516   33    7        1  secondary      no     -333     yes   no  cellular
# 4517   57    6        1   tertiary     yes    -3313     yes  yes   unknown
# 4518   57    9        1  secondary      no      295      no   no  cellular
# 4519   28    1        1  secondary      no     1137      no   no  cellular
# 4520   44    2        2   tertiary      no     1136     yes  yes  cellular
#
#       day month  duration  campaign  pdays  previous poutcome   y
# ...

# %%
m1['education']=l1.fit_transform(m1['education'])

# %%
m1
# Out:
#       age  job  marital  education default  balance housing loan   contact  \
# 0      30   10        1          0      no     1787      no   no  cellular
# 1      33    7        1          1      no     4789     yes  yes  cellular
# 2      35    4        2          2      no     1350     yes   no  cellular
# 3      30    4        1          2      no     1476     yes  yes   unknown
# 4      59    1        1          1      no        0     yes   no   unknown
# ...   ...  ...      ...        ...     ...      ...     ...  ...       ...
# 4516   33    7        1          1      no     -333     yes   no  cellular
# 4517   57    6        1          2     yes    -3313     yes  yes   unknown
# 4518   57    9        1          1      no      295      no   no  cellular
# 4519   28    1        1          1      no     1137      no   no  cellular
# 4520   44    2        2          2      no     1136     yes  yes  cellular
#
#       day month  duration  campaign  pdays  previous poutcome   y
# ...

# %%
m1['default']=l1.fit_transform(m1['default'])

# %%
m1['housing']=l1.fit_transform(m1['housing'])

# %%
m1['loan']=l1.fit_transform(m1['loan'])

# %%
m1['contact']=l1.fit_transform(m1['contact'])

# %%
m1['month']=l1.fit_transform(m1['month'])

# %%
m1
# Out:
#       age  job  marital  education  default  balance  housing  loan  contact  \
# 0      30   10        1          0        0     1787        0     0        0
# 1      33    7        1          1        0     4789        1     1        0
# 2      35    4        2          2        0     1350        1     0        0
# 3      30    4        1          2        0     1476        1     1        2
# 4      59    1        1          1        0        0        1     0        2
# ...   ...  ...      ...        ...      ...      ...      ...   ...      ...
# 4516   33    7        1          1        0     -333        1     0        0
# 4517   57    6        1          2        1    -3313        1     1        2
# 4518   57    9        1          1        0      295        0     0        0
# 4519   28    1        1          1        0     1137        0     0        0
# 4520   44    2        2          2        0     1136        1     1        0
#
# ...

# %%
m1['poutcome']=l1.fit_transform(m1['poutcome'])

# %%
m1['y']=l1.fit_transform(m1['y'])

# %%
m1
# Out:
#       age  job  marital  education  default  balance  housing  loan  contact  \
# 0      30   10        1          0        0     1787        0     0        0
# 1      33    7        1          1        0     4789        1     1        0
# 2      35    4        2          2        0     1350        1     0        0
# 3      30    4        1          2        0     1476        1     1        2
# 4      59    1        1          1        0        0        1     0        2
# ...   ...  ...      ...        ...      ...      ...      ...   ...      ...
# 4516   33    7        1          1        0     -333        1     0        0
# 4517   57    6        1          2        1    -3313        1     1        2
# 4518   57    9        1          1        0      295        0     0        0
# 4519   28    1        1          1        0     1137        0     0        0
# 4520   44    2        2          2        0     1136        1     1        0
#
# ...

# %%
m1.head()
# Out:
#    age  job  marital  education  default  balance  housing  loan  contact  \
# 0   30   10        1          0        0     1787        0     0        0
# 1   33    7        1          1        0     4789        1     1        0
# 2   35    4        2          2        0     1350        1     0        0
# 3   30    4        1          2        0     1476        1     1        2
# 4   59    1        1          1        0        0        1     0        2
#
#    day  month  duration  campaign  pdays  previous  poutcome  y
# 0   19     10        79         1     -1         0         3  0
# 1   11      8       220         1    339         4         0  0
# 2   16      0       185         1    330         1         0  0
# 3    3      6       199         4     -1         0         3  0
# 4    5      8       226         1     -1         0         3  0

# %%
np.mean(m1['balance'])
# Out:
# 1422.6578190665782

# %%
m1.describe()
# Out:
#                age          job      marital    education      default  \
# count  4521.000000  4521.000000  4521.000000  4521.000000  4521.000000
# mean     41.170095     4.411192     1.147755     1.231365     0.016810
# std      10.576211     3.255716     0.599650     0.748744     0.128575
# min      19.000000     0.000000     0.000000     0.000000     0.000000
# 25%      33.000000     1.000000     1.000000     1.000000     0.000000
# 50%      39.000000     4.000000     1.000000     1.000000     0.000000
# 75%      49.000000     7.000000     2.000000     2.000000     0.000000
# max      87.000000    11.000000     2.000000     3.000000     1.000000
#
#             balance      housing         loan      contact          day  \
# count   4521.000000  4521.000000  4521.000000  4521.000000  4521.000000
# mean    1422.657819     0.566025     0.152842     0.652289    15.915284
# std     3009.638142     0.495676     0.359875     0.901498     8.247667
# ...

# %%
cor=m1.corr().abs()

# %%
cor
# Out:
#                 age       job   marital  education   default   balance  \
# age        1.000000  0.021500  0.381485   0.121613  0.017885  0.083820
# job        0.021500  1.000000  0.069390   0.170160  0.008324  0.009797
# marital    0.381485  0.069390  1.000000   0.102714  0.020745  0.024971
# education  0.121613  0.170160  0.102714   1.000000  0.010534  0.057725
# default    0.017885  0.008324  0.020745   0.010534  1.000000  0.070886
# balance    0.083820  0.009797  0.024971   0.057725  0.070886  1.000000
# housing    0.193888  0.128353  0.029851   0.087070  0.006881  0.050227
# loan       0.011250  0.040245  0.045210   0.054086  0.063994  0.071349
# contact    0.015161  0.074068  0.068236   0.110554  0.008448  0.009665
# day        0.017853  0.012865  0.008794   0.014926  0.013261  0.008677
# month      0.040714  0.096613  0.035855   0.050086  0.014297  0.023113
# duration   0.002367  0.006739  0.006619   0.014878  0.011615  0.015950
# ...

# %%
c=m1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4521 entries, 0 to 4520
# Data columns (total 17 columns):
# age          4521 non-null int64
# job          4521 non-null int32
# marital      4521 non-null int32
# education    4521 non-null int32
# default      4521 non-null int32
# balance      4521 non-null int64
# housing      4521 non-null int32
# loan         4521 non-null int32
# contact      4521 non-null int32
# day          4521 non-null int64
# month        4521 non-null int32
# duration     4521 non-null int64
# campaign     4521 non-null int64
# pdays        4521 non-null int64
# previous     4521 non-null int64
# poutcome     4521 non-null int32
# y            4521 non-null int32
# dtypes: int32(10), int64(7)
# memory usage: 424.0 KB

# %%
x=m1.iloc[:,0:16]
y=m1.iloc[:,-1]

from sklearn.model_selection import train_test_split

y
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 4516    0
# 4517    0
# 4518    0
# 4519    0
# 4520    0
# Name: y, Length: 4521, dtype: int32

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=1)

# %%
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression()
lr.fit(x_train,y_train)

p=lr.predict(x_test)

lr.score(x_train,y_train)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# 0.8982300884955752

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,p)*100
# Out:
# 87.17759764185703

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(y_test,p)
# Out:
# array([[1150,   32],
#        [ 142,   33]], dtype=int64)

# %%
from sklearn.metrics import classification_report
classification_report(y_test,p)
# Out:
# '              precision    recall  f1-score   support\n\n           0       0.89      0.97      0.93      1182\n           1       0.51      0.19      0.27       175\n\n    accuracy                           0.87      1357\n   macro avg       0.70      0.58      0.60      1357\nweighted avg       0.84      0.87      0.85      1357\n'

# %%
from sklearn.metrics import mean_absolute_error
nps=mean_absolute_error(y_test,p)

# %%
nps*100
# Out:
# 12.822402358142963

# %%
npss=100-nps*100

# %%
npss
# Out:
# 87.17759764185703

# %%
m1.to_csv('C:\\Users\\Boss\\Downloads\\bank2.csv')

# %%
m2=pd.read_csv('C:\\Users\\Boss\\Downloads\\bank2.csv',sep=',')

# %%
m2
# Out:
#       Unnamed: 0  age  job  marital  education  default  balance  housing  \
# 0              0   30   10        1          0        0     1787        0
# 1              1   33    7        1          1        0     4789        1
# 2              2   35    4        2          2        0     1350        1
# 3              3   30    4        1          2        0     1476        1
# 4              4   59    1        1          1        0        0        1
# ...          ...  ...  ...      ...        ...      ...      ...      ...
# 4516        4516   33    7        1          1        0     -333        1
# 4517        4517   57    6        1          2        1    -3313        1
# 4518        4518   57    9        1          1        0      295        0
# 4519        4519   28    1        1          1        0     1137        0
# 4520        4520   44    2        2          2        0     1136        1
#
#       loan  contact  day  month  duration  campaign  pdays  previous  \
# ...

# %%
from sklearn.tree import DecisionTreeClassifier
dt=DecisionTreeClassifier()
dt.fit(x_train,y_train)

p=dt.predict(x_test)

dt.score(x_train,y_train)
# Out:
# 1.0

# %%
accuracy_score(y_test,p)*100
# Out:
# 85.85114222549743

# %%
from sklearn.ensemble import RandomForestClassifier
dt=RandomForestClassifier()
dt.fit(x_train,y_train)

p=dt.predict(x_test)

dt.score(x_train,y_train)
accuracy_score(y_test,p)*100
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# 87.54605747973471

# %%
from xgboost import XGBClassifier

# %%
dt=XGBClassifier()
dt.fit(x_train,y_train)

p=dt.predict(x_test)

dt.score(x_train,y_train)
accuracy_score(y_test,p)*100
# Out:
# 89.16728076639646

# %%
from sklearn.linear_model import LinearRegression
dt=LinearRegression()
dt.fit(x_train,y_train)

p=dt.predict(x_test)

dt.score(x_train,y_train)
#accuracy_score(y_test,p)
# Out:
# 0.20733316294275483

# %%
nps=mean_absolute_error(y_test,p)

# %%
nps
# Out:
# 0.18693071253910673

# %%
 
import matplotlib.pyplot as plt  
import seaborn as seabornInstance 
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression
from sklearn import metrics
# %matplotlib inline

# %%
np.sqrt(metrics.mean_squared_error(y_test, p))
# Out:
# 0.30128409026873465

# %%
(metrics.mean_squared_error(y_test, p))
# Out:
# 0.09077210304905906

# %%
from sklearn.svm import LinearSVC
dt=LinearSVC()
dt.fit(x_train,y_train)

p=dt.predict(x_test)

dt.score(x_train,y_train)
accuracy_score(y_test,p)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\svm\base.py:929: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# 0.7686072218128224

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
from sklearn import datasets

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.pipeline import make_pipeline
